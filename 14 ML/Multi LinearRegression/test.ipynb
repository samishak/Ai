# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df_index=pd.read_csv('economic_index.csv')

# %%
df_index.head()
# Out:
#    Unnamed: 0  year  month  interest_rate  unemployment_rate  index_price
# 0           0  2017     12           2.75                5.3         1464
# 1           1  2017     11           2.50                5.3         1394
# 2           2  2017     10           2.50                5.3         1357
# 3           3  2017      9           2.50                5.3         1293
# 4           4  2017      8           2.50                5.4         1256

# %%
#drop unnecessary columns we don't neet the month and year 
df_index.drop(columns=['Unnamed: 0',"year","month" ],axis=1,inplace=True)

# %%
df_index.head()
# Out:
#    interest_rate  unemployment_rate  index_price
# 0           2.75                5.3         1464
# 1           2.50                5.3         1394
# 2           2.50                5.3         1357
# 3           2.50                5.3         1293
# 4           2.50                5.4         1256

# %%
##check the null values 
df_index.isnull().sum()
# Out:
# interest_rate        0
# unemployment_rate    0
# index_price          0
# dtype: int64

# %%
## let's do some visualization 
import seaborn as sns
sns.pairplot(df_index)

# %%
df_index.corr()
# Out:
#                    interest_rate  unemployment_rate  index_price
# interest_rate           1.000000          -0.925814     0.935793
# unemployment_rate      -0.925814           1.000000    -0.922338
# index_price             0.935793          -0.922338     1.000000

# %%
plt.scatter(df_index['interest_rate'],df_index['unemployment_rate'],color='r')
plt.xlabel("Interest rate")
plt.ylabel("unemployment rate")
# Out:
# Text(0, 0.5, 'unemployment rate')

# %%
#independent and dependent feature 
X=df_index.iloc[:,:-1] ## from all the feature just remove the last one 
y=df_index.iloc[:,-1]#take the last column

# %%
X.head(),y
# Out:
# (   interest_rate  unemployment_rate
#  0           2.75                5.3
#  1           2.50                5.3
#  2           2.50                5.3
#  3           2.50                5.3
#  4           2.50                5.4,
#  0     1464
#  1     1394
#  2     1357
#  3     1293
#  4     1256
#  5     1254
#  6     1234
#  7     1195
#  8     1159
#  9     1167
#  10    1130
#  11    1075
#  12    1047
#  13     965
#  14     943
#  15     958
#  16     971
#  17     949
#  18     884
#  19     866
#  20     876
#  21     822
#  22     704
#  23     719
#  Name: index_price, dtype: int64)

# %%
#train test split 
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
import seaborn as sns

# %%
sns.regplot(df_index['interest_rate'],df_index['index_price'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 sns.regplot(df_index['interest_rate'],df_index['index_price'])
#
# TypeError: regplot() takes from 0 to 1 positional arguments but 2 were given
