# %%
import logging 

#create a logger for module 1 

logger1=logging.getLogger("module 1")
logger1.setLevel(logging.DEBUG)

## create a logger for module 2 

logger2=logging.getLogger("module 2")
logger2.setLevel(logging.WARNING)

#configure logging settings 
logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    force=True
)

# %%
#log message with different loggers 

logger1.debug("this is debug message for module 1 ")
logger2.warning("this is a warning message for module 2 ")
logger2.error("this is a error msg for module 2")
# Out:
# 2026-01-01 15:37:16 - module 1 - DEBUG - this is debug message for module 1
# 2026-01-01 15:37:16 - module 2 - WARNING - this is a warning message for module 2
# 2026-01-01 15:37:16 - module 2 - ERROR - this is a error msg for module 2
